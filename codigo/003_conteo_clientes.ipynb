# %% [markdown]
# <h2> Conteo de personas. </h2>
# <h3> Computer Vision con Python - OpenCV</h3>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO
from csv import writer

# %%
# Enttrada del video
video_path = "../videos/people-detection.mp4"

# Saluda del video
output_path = "../videos/output_tienda.avi"

# %%
def signed_distance(point, line):
    """
    Calcula la distancia con signo de un punto a una línea.
    Retorna:
        float: Distancia con signo del punto a la línea.
    """
    x, y = point
    (x1, y1), (x2, y2) = line
    num = (y2 - y1) * x - (x2 - x1) * y + x2 * y1 - y2 * x1
    den = np.sqrt((y2 - y1) ** 2 + (x2 - x1) ** 2)
    return num / den if den != 0 else 0

# Definir las líneas de conteo
line1 = ((130, 120), (25, 300)) #((130, 180), (25, 300))
line2 = ((650, 175), (720, 275))

# Contadores para cada línea
count_line1 = 0
count_line2 = 0

# Umbral para asociar detecciones entre frames
distance_threshold = 25 #50

# Lista para almacenar los centroides del frame anterior
prev_centroids = []

# Cargar el modelo YOLO (se asume que "person" es la clase 0 en COCO)
model = YOLO("yolo11n.pt")

# Abrir video de entrada y configurar VideoWriter para el video de salida
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    raise ValueError("No se pudo abrir el video de entrada.")

fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'XVID')
writer = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Detección con YOLOv11
    results = model(frame, conf=0.7)
    # Accedemos al primer resultado de la lista
    boxes_obj = results[0].boxes

    current_centroids = []
    if boxes_obj is not None and len(boxes_obj) > 0:
        # Extraer las cajas y las clases como arrays NumPy
        bboxes = boxes_obj.xyxy.cpu().numpy()  # Array de shape (N,4)
        classes = boxes_obj.cls.cpu().numpy()    # Array de shape (N,)
        # Filtrar detecciones de "person" comprobando que la clase sea 0
        for i in range(len(bboxes)):
            if int(classes[i]) == 0:
                x1, y1, x2, y2 = map(int, bboxes[i])
                centroid = ((x1 + x2) // 2, (y1 + y2) // 2)
                current_centroids.append(centroid)
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.circle(frame, centroid, 4, (0, 255, 0), -1)

    cv2.line(frame, line1[0], line1[1], (255, 0, 0), 2)
    cv2.line(frame, line2[0], line2[1], (0, 0, 255), 2)

    for curr in current_centroids:
        best_distance = float('inf')
        best_prev = None
        for prev in prev_centroids:
            d = np.linalg.norm(np.array(curr) - np.array(prev))
            if d < best_distance and d < distance_threshold:
                best_distance = d
                best_prev = prev
        if best_prev is not None:
            # Verificar cruce de la línea 1
            prev_side1 = signed_distance(best_prev, line1)
            curr_side1 = signed_distance(curr, line1)
            if prev_side1 * curr_side1 < 0:
                count_line1 += 1
            # Verificar cruce de la línea 2
            prev_side2 = signed_distance(best_prev, line2)
            curr_side2 = signed_distance(curr, line2)
            if prev_side2 * curr_side2 < 0:
                count_line2 += 1

    # Dibujar los contadores en el frame
    cv2.putText(frame, f"Seccion Celulares: {count_line1}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    cv2.putText(frame, f"Seccion Televisores: {count_line2}", (10, 70),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Escribir el frame procesado en el video de salida
    writer.write(frame)

    # Actualizar los centroides del frame anterior
    prev_centroids = current_centroids.copy()

cap.release()
writer.release()
print(f"Video procesado y guardado en: {output_path}")
# Out:
# 0: 384x640 (no detections), 86.9ms
# Speed: 1.7ms preprocess, 86.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.0ms
# Speed: 1.4ms preprocess, 72.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.9ms
# Speed: 1.5ms preprocess, 71.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.8ms
# Speed: 2.2ms preprocess, 76.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.3ms
# Speed: 2.0ms preprocess, 71.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.2ms
# Speed: 1.4ms preprocess, 73.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.9ms
# Speed: 1.4ms preprocess, 78.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.1ms
# Speed: 1.6ms preprocess, 69.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.5ms
# Speed: 2.2ms preprocess, 70.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.4ms
# Speed: 2.0ms preprocess, 70.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.0ms
# Speed: 1.5ms preprocess, 75.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.7ms
# Speed: 1.4ms preprocess, 80.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.4ms
# Speed: 2.8ms preprocess, 76.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.8ms
# Speed: 1.8ms preprocess, 69.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 1.4ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.4ms
# Speed: 2.3ms preprocess, 72.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.2ms
# Speed: 1.9ms preprocess, 83.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.5ms
# Speed: 1.5ms preprocess, 78.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.8ms
# Speed: 1.4ms preprocess, 69.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.7ms
# Speed: 1.9ms preprocess, 68.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 72.3ms
# Speed: 1.4ms preprocess, 72.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.0ms
# Speed: 1.4ms preprocess, 73.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.6ms
# Speed: 1.6ms preprocess, 70.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.2ms
# Speed: 2.4ms preprocess, 71.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.8ms
# Speed: 1.4ms preprocess, 69.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.2ms
# Speed: 1.4ms preprocess, 72.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.8ms
# Speed: 1.5ms preprocess, 68.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.5ms
# Speed: 1.4ms preprocess, 72.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.2ms
# Speed: 1.5ms preprocess, 70.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.0ms
# Speed: 1.5ms preprocess, 74.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.0ms
# Speed: 1.4ms preprocess, 70.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.9ms
# Speed: 1.5ms preprocess, 68.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.3ms
# Speed: 1.4ms preprocess, 70.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.0ms
# Speed: 1.4ms preprocess, 70.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.3ms
# Speed: 1.5ms preprocess, 70.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.6ms
# Speed: 1.4ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.4ms
# Speed: 1.4ms preprocess, 71.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.0ms
# Speed: 1.4ms preprocess, 70.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.6ms
# Speed: 1.4ms preprocess, 70.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.4ms
# Speed: 1.4ms preprocess, 68.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.6ms
# Speed: 2.0ms preprocess, 78.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.6ms
# Speed: 1.4ms preprocess, 68.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 84.5ms
# Speed: 1.5ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 111.8ms
# Speed: 1.6ms preprocess, 111.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 84.0ms
# Speed: 1.6ms preprocess, 84.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.4ms
# Speed: 1.5ms preprocess, 72.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.4ms
# Speed: 1.7ms preprocess, 67.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 79.6ms
# Speed: 1.5ms preprocess, 79.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.5ms
# Speed: 1.8ms preprocess, 76.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.5ms
# Speed: 1.5ms preprocess, 77.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.5ms
# Speed: 1.8ms preprocess, 69.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.8ms
# Speed: 1.5ms preprocess, 77.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.9ms
# Speed: 1.7ms preprocess, 70.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.2ms
# Speed: 1.5ms preprocess, 77.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.7ms
# Speed: 1.7ms preprocess, 74.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.0ms
# Speed: 1.6ms preprocess, 70.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 85.6ms
# Speed: 1.4ms preprocess, 85.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.6ms
# Speed: 2.3ms preprocess, 101.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.4ms
# Speed: 1.5ms preprocess, 67.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.8ms
# Speed: 1.5ms preprocess, 106.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.4ms
# Speed: 1.5ms preprocess, 73.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.3ms
# Speed: 1.5ms preprocess, 70.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.4ms
# Speed: 1.5ms preprocess, 70.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.2ms
# Speed: 1.5ms preprocess, 73.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.9ms
# Speed: 1.5ms preprocess, 70.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.7ms
# Speed: 1.6ms preprocess, 70.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.9ms
# Speed: 1.8ms preprocess, 68.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.5ms
# Speed: 1.5ms preprocess, 72.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.4ms
# Speed: 1.5ms preprocess, 73.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 89.1ms
# Speed: 1.4ms preprocess, 89.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 82.4ms
# Speed: 1.6ms preprocess, 82.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.0ms
# Speed: 1.5ms preprocess, 72.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 89.3ms
# Speed: 1.5ms preprocess, 89.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.1ms
# Speed: 1.5ms preprocess, 73.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.1ms
# Speed: 1.5ms preprocess, 68.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.4ms
# Speed: 2.3ms preprocess, 74.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.6ms
# Speed: 1.6ms preprocess, 70.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.1ms
# Speed: 1.4ms preprocess, 69.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.2ms
# Speed: 2.0ms preprocess, 67.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.1ms
# Speed: 1.4ms preprocess, 71.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.7ms
# Speed: 1.4ms preprocess, 68.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.0ms
# Speed: 2.2ms preprocess, 75.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.3ms
# Speed: 1.4ms preprocess, 70.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.0ms
# Speed: 1.4ms preprocess, 70.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.6ms
# Speed: 1.9ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.2ms
# Speed: 1.5ms preprocess, 70.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.0ms
# Speed: 1.5ms preprocess, 67.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.2ms
# Speed: 1.4ms preprocess, 71.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.7ms
# Speed: 1.4ms preprocess, 71.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.6ms
# Speed: 2.0ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 1.4ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.8ms
# Speed: 1.4ms preprocess, 67.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.9ms
# Speed: 1.4ms preprocess, 67.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.2ms
# Speed: 1.7ms preprocess, 68.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.1ms
# Speed: 1.5ms preprocess, 67.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.3ms
# Speed: 1.4ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.6ms
# Speed: 1.9ms preprocess, 84.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.6ms
# Speed: 1.5ms preprocess, 74.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 1.4ms preprocess, 69.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.9ms
# Speed: 1.5ms preprocess, 71.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.9ms
# Speed: 1.4ms preprocess, 78.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.9ms
# Speed: 1.5ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.7ms
# Speed: 1.7ms preprocess, 69.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.4ms
# Speed: 1.4ms preprocess, 82.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.3ms
# Speed: 1.6ms preprocess, 71.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.4ms
# Speed: 1.4ms preprocess, 68.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.7ms
# Speed: 1.9ms preprocess, 67.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.9ms
# Speed: 1.5ms preprocess, 68.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.3ms
# Speed: 1.5ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.7ms
# Speed: 1.4ms preprocess, 67.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.3ms
# Speed: 1.4ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.3ms
# Speed: 1.4ms preprocess, 68.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.3ms
# Speed: 1.6ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.6ms
# Speed: 1.4ms preprocess, 66.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 1.4ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.6ms
# Speed: 1.6ms preprocess, 68.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.1ms
# Speed: 1.4ms preprocess, 71.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.1ms
# Speed: 1.8ms preprocess, 74.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.0ms
# Speed: 2.2ms preprocess, 83.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.8ms
# Speed: 1.6ms preprocess, 87.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.5ms
# Speed: 2.4ms preprocess, 71.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.5ms
# Speed: 1.8ms preprocess, 67.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.2ms
# Speed: 1.4ms preprocess, 80.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.6ms
# Speed: 1.5ms preprocess, 97.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.7ms
# Speed: 1.8ms preprocess, 65.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.2ms
# Speed: 1.4ms preprocess, 70.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.5ms
# Speed: 1.6ms preprocess, 67.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.1ms
# Speed: 1.4ms preprocess, 88.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.3ms
# Speed: 1.7ms preprocess, 77.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 1.4ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.4ms
# Speed: 1.7ms preprocess, 74.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.3ms
# Speed: 1.5ms preprocess, 87.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.4ms
# Speed: 1.6ms preprocess, 89.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.9ms
# Speed: 1.5ms preprocess, 73.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.0ms
# Speed: 1.5ms preprocess, 95.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.2ms
# Speed: 2.4ms preprocess, 90.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.0ms
# Speed: 1.5ms preprocess, 98.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.5ms
# Speed: 1.7ms preprocess, 76.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.3ms
# Speed: 1.5ms preprocess, 82.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.1ms
# Speed: 1.5ms preprocess, 70.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.7ms
# Speed: 1.4ms preprocess, 69.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.4ms
# Speed: 1.4ms preprocess, 70.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.2ms
# Speed: 2.3ms preprocess, 68.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.7ms
# Speed: 1.5ms preprocess, 71.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.5ms
# Speed: 2.2ms preprocess, 71.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.4ms
# Speed: 1.5ms preprocess, 69.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.0ms
# Speed: 1.4ms preprocess, 70.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.0ms
# Speed: 2.4ms preprocess, 84.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.9ms
# Speed: 2.4ms preprocess, 78.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.7ms
# Speed: 1.4ms preprocess, 69.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.2ms
# Speed: 2.1ms preprocess, 78.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.1ms
# Speed: 1.6ms preprocess, 70.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.4ms
# Speed: 1.5ms preprocess, 70.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.5ms
# Speed: 1.4ms preprocess, 71.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.7ms
# Speed: 1.5ms preprocess, 70.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.6ms
# Speed: 1.6ms preprocess, 69.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.1ms
# Speed: 1.4ms preprocess, 71.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 1.5ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.7ms
# Speed: 1.5ms preprocess, 68.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.8ms
# Speed: 1.5ms preprocess, 69.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 1.5ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.1ms
# Speed: 1.5ms preprocess, 71.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.2ms
# Speed: 1.4ms preprocess, 70.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.9ms
# Speed: 1.9ms preprocess, 71.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.4ms
# Speed: 1.4ms preprocess, 82.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.1ms
# Speed: 1.6ms preprocess, 75.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.2ms
# Speed: 1.7ms preprocess, 77.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.7ms
# Speed: 1.5ms preprocess, 72.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.9ms
# Speed: 1.6ms preprocess, 70.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.6ms
# Speed: 1.5ms preprocess, 70.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.2ms
# Speed: 1.9ms preprocess, 71.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.9ms
# Speed: 1.7ms preprocess, 67.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.4ms
# Speed: 1.4ms preprocess, 96.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.5ms
# Speed: 3.2ms preprocess, 86.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.1ms
# Speed: 1.5ms preprocess, 89.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.3ms
# Speed: 1.5ms preprocess, 77.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.3ms
# Speed: 1.5ms preprocess, 72.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.5ms
# Speed: 1.4ms preprocess, 70.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 74.2ms
# Speed: 1.5ms preprocess, 74.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.9ms
# Speed: 1.5ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.9ms
# Speed: 1.4ms preprocess, 69.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.3ms
# Speed: 1.5ms preprocess, 69.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.6ms
# Speed: 1.5ms preprocess, 69.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.5ms
# Speed: 1.5ms preprocess, 69.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.9ms
# Speed: 1.5ms preprocess, 70.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.7ms
# Speed: 2.4ms preprocess, 71.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.8ms
# Speed: 1.7ms preprocess, 70.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.0ms
# Speed: 1.6ms preprocess, 70.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 72.4ms
# Speed: 1.5ms preprocess, 72.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.3ms
# Speed: 1.4ms preprocess, 70.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 75.3ms
# Speed: 2.6ms preprocess, 75.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.8ms
# Speed: 1.5ms preprocess, 70.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.4ms
# Speed: 1.6ms preprocess, 70.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.6ms
# Speed: 1.5ms preprocess, 69.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.3ms
# Speed: 1.5ms preprocess, 71.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.2ms
# Speed: 1.7ms preprocess, 71.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 74.8ms
# Speed: 1.8ms preprocess, 74.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 74.1ms
# Speed: 2.3ms preprocess, 74.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 79.5ms
# Speed: 1.7ms preprocess, 79.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.1ms
# Speed: 1.5ms preprocess, 71.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.8ms
# Speed: 1.5ms preprocess, 70.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 83.6ms
# Speed: 1.6ms preprocess, 83.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 81.4ms
# Speed: 1.5ms preprocess, 81.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.2ms
# Speed: 1.6ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.7ms
# Speed: 1.5ms preprocess, 69.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.5ms
# Speed: 1.7ms preprocess, 70.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.3ms
# Speed: 1.7ms preprocess, 68.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.4ms
# Speed: 1.5ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.6ms
# Speed: 1.4ms preprocess, 68.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 73.0ms
# Speed: 1.5ms preprocess, 73.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.6ms
# Speed: 2.1ms preprocess, 67.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 74.5ms
# Speed: 1.5ms preprocess, 74.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.3ms
# Speed: 1.5ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.4ms
# Speed: 1.5ms preprocess, 71.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.9ms
# Speed: 1.5ms preprocess, 70.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.8ms
# Speed: 1.4ms preprocess, 69.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.6ms
# Speed: 1.8ms preprocess, 70.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.4ms
# Speed: 1.6ms preprocess, 71.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.7ms
# Speed: 1.5ms preprocess, 69.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.0ms
# Speed: 1.4ms preprocess, 71.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.9ms
# Speed: 1.4ms preprocess, 67.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.7ms
# Speed: 2.1ms preprocess, 69.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.8ms
# Speed: 1.4ms preprocess, 67.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.1ms
# Speed: 1.6ms preprocess, 72.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.7ms
# Speed: 1.5ms preprocess, 70.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.9ms
# Speed: 1.4ms preprocess, 69.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 85.3ms
# Speed: 1.5ms preprocess, 85.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 90.4ms
# Speed: 1.8ms preprocess, 90.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 84.5ms
# Speed: 1.6ms preprocess, 84.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 85.7ms
# Speed: 1.8ms preprocess, 85.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 77.1ms
# Speed: 1.5ms preprocess, 77.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.9ms
# Speed: 1.5ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.3ms
# Speed: 1.4ms preprocess, 70.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 108.1ms
# Speed: 1.6ms preprocess, 108.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 87.1ms
# Speed: 1.6ms preprocess, 87.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 73.2ms
# Speed: 1.7ms preprocess, 73.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.4ms
# Speed: 1.5ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.9ms
# Speed: 1.5ms preprocess, 69.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.1ms
# Speed: 1.7ms preprocess, 71.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.7ms
# Speed: 1.5ms preprocess, 71.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.4ms
# Speed: 1.5ms preprocess, 71.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.5ms
# Speed: 1.4ms preprocess, 69.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 92.7ms
# Speed: 1.6ms preprocess, 92.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.2ms
# Speed: 1.8ms preprocess, 81.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.9ms
# Speed: 1.4ms preprocess, 71.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.5ms
# Speed: 2.0ms preprocess, 70.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.5ms
# Speed: 1.4ms preprocess, 70.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.9ms
# Speed: 1.5ms preprocess, 78.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.7ms
# Speed: 1.4ms preprocess, 75.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.5ms
# Speed: 1.5ms preprocess, 68.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.8ms
# Speed: 1.5ms preprocess, 70.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.0ms
# Speed: 1.5ms preprocess, 66.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.3ms
# Speed: 1.5ms preprocess, 68.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.8ms
# Speed: 1.4ms preprocess, 67.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.0ms
# Speed: 1.5ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.7ms
# Speed: 1.8ms preprocess, 85.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.6ms
# Speed: 1.7ms preprocess, 75.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.6ms
# Speed: 1.5ms preprocess, 67.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.6ms
# Speed: 1.4ms preprocess, 68.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.3ms
# Speed: 1.4ms preprocess, 71.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 1.5ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.9ms
# Speed: 1.4ms preprocess, 67.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.3ms
# Speed: 1.4ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.3ms
# Speed: 1.4ms preprocess, 70.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.0ms
# Speed: 1.5ms preprocess, 68.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.9ms
# Speed: 1.5ms preprocess, 68.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.4ms
# Speed: 1.6ms preprocess, 68.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.6ms
# Speed: 1.5ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.8ms
# Speed: 1.6ms preprocess, 69.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.1ms
# Speed: 1.5ms preprocess, 69.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.4ms
# Speed: 1.4ms preprocess, 68.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.8ms
# Speed: 1.7ms preprocess, 70.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.4ms
# Speed: 1.4ms preprocess, 68.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.4ms
# Speed: 1.8ms preprocess, 74.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.8ms
# Speed: 1.6ms preprocess, 70.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.3ms
# Speed: 1.5ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.7ms
# Speed: 1.4ms preprocess, 82.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.0ms
# Speed: 1.5ms preprocess, 79.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.2ms
# Speed: 1.6ms preprocess, 68.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.9ms
# Speed: 1.7ms preprocess, 67.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.0ms
# Speed: 1.5ms preprocess, 67.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.3ms
# Speed: 1.4ms preprocess, 70.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.5ms
# Speed: 1.5ms preprocess, 73.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.1ms
# Speed: 2.6ms preprocess, 88.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.3ms
# Speed: 1.8ms preprocess, 72.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.9ms
# Speed: 1.4ms preprocess, 71.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.5ms
# Speed: 1.5ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 108.2ms
# Speed: 2.2ms preprocess, 108.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.9ms
# Speed: 1.5ms preprocess, 71.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.9ms
# Speed: 2.3ms preprocess, 67.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.6ms
# Speed: 1.5ms preprocess, 68.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.7ms
# Speed: 1.9ms preprocess, 70.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.9ms
# Speed: 1.5ms preprocess, 66.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.9ms
# Speed: 1.5ms preprocess, 70.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.6ms
# Speed: 1.4ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.2ms
# Speed: 1.5ms preprocess, 68.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.3ms
# Speed: 1.7ms preprocess, 67.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.6ms
# Speed: 1.4ms preprocess, 69.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.1ms
# Speed: 1.5ms preprocess, 75.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.2ms
# Speed: 1.4ms preprocess, 68.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.0ms
# Speed: 1.5ms preprocess, 70.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.1ms
# Speed: 1.4ms preprocess, 70.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.3ms
# Speed: 1.6ms preprocess, 67.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.9ms
# Speed: 1.4ms preprocess, 66.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.0ms
# Speed: 1.6ms preprocess, 68.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.7ms
# Speed: 1.5ms preprocess, 68.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.4ms
# Speed: 1.5ms preprocess, 67.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.0ms
# Speed: 1.4ms preprocess, 70.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.3ms
# Speed: 1.5ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.6ms
# Speed: 1.4ms preprocess, 69.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.6ms
# Speed: 1.5ms preprocess, 80.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.3ms
# Speed: 1.5ms preprocess, 78.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.4ms
# Speed: 2.4ms preprocess, 71.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.7ms
# Speed: 1.7ms preprocess, 68.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.3ms
# Speed: 1.5ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 1.5ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.7ms
# Speed: 1.5ms preprocess, 71.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.1ms
# Speed: 1.5ms preprocess, 69.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.2ms
# Speed: 1.5ms preprocess, 78.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.9ms
# Speed: 1.5ms preprocess, 80.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.8ms
# Speed: 1.5ms preprocess, 67.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.3ms
# Speed: 1.5ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.1ms
# Speed: 1.6ms preprocess, 68.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.2ms
# Speed: 1.5ms preprocess, 68.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.6ms
# Speed: 2.1ms preprocess, 71.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.3ms
# Speed: 1.5ms preprocess, 68.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.2ms
# Speed: 1.4ms preprocess, 70.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.0ms
# Speed: 1.6ms preprocess, 68.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.6ms
# Speed: 1.4ms preprocess, 70.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.3ms
# Speed: 1.5ms preprocess, 70.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.6ms
# Speed: 1.6ms preprocess, 68.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.6ms
# Speed: 1.5ms preprocess, 69.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 1.8ms preprocess, 69.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.5ms
# Speed: 1.4ms preprocess, 67.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.4ms
# Speed: 1.7ms preprocess, 70.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.5ms
# Speed: 1.7ms preprocess, 105.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.3ms
# Speed: 1.5ms preprocess, 76.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.7ms
# Speed: 1.5ms preprocess, 66.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 83.2ms
# Speed: 1.6ms preprocess, 83.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 79.8ms
# Speed: 1.5ms preprocess, 79.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.5ms
# Speed: 1.6ms preprocess, 70.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.5ms
# Speed: 1.5ms preprocess, 68.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.4ms
# Speed: 1.4ms preprocess, 68.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 73.1ms
# Speed: 1.5ms preprocess, 73.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.1ms
# Speed: 1.4ms preprocess, 68.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.9ms
# Speed: 1.5ms preprocess, 67.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.8ms
# Speed: 1.8ms preprocess, 68.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.6ms
# Speed: 1.5ms preprocess, 66.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.0ms
# Speed: 1.5ms preprocess, 70.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.9ms
# Speed: 1.5ms preprocess, 68.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 79.4ms
# Speed: 2.2ms preprocess, 79.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 73.2ms
# Speed: 1.5ms preprocess, 73.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 69.4ms
# Speed: 1.5ms preprocess, 69.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 67.0ms
# Speed: 1.6ms preprocess, 67.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 69.3ms
# Speed: 1.7ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 67.0ms
# Speed: 1.6ms preprocess, 67.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 66.9ms
# Speed: 1.4ms preprocess, 66.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 71.8ms
# Speed: 1.5ms preprocess, 71.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 67.3ms
# Speed: 1.5ms preprocess, 67.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 69.1ms
# Speed: 1.6ms preprocess, 69.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 75.8ms
# Speed: 1.5ms preprocess, 75.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 81.4ms
# Speed: 1.6ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 69.4ms
# Speed: 1.5ms preprocess, 69.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 70.9ms
# ...
#
# 0: 384x640 (no detections), 85.2ms
# Speed: 1.7ms preprocess, 85.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.2ms
# Speed: 1.5ms preprocess, 82.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.7ms
# Speed: 1.5ms preprocess, 70.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.6ms
# Speed: 1.8ms preprocess, 73.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.5ms
# Speed: 1.5ms preprocess, 68.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.7ms
# Speed: 1.4ms preprocess, 70.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.8ms
# Speed: 1.6ms preprocess, 87.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.7ms
# Speed: 1.7ms preprocess, 80.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.2ms
# Speed: 1.7ms preprocess, 74.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.4ms
# Speed: 1.5ms preprocess, 71.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.0ms
# Speed: 1.4ms preprocess, 69.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.0ms
# Speed: 1.4ms preprocess, 70.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.0ms
# Speed: 1.5ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.6ms
# Speed: 1.4ms preprocess, 70.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.6ms
# Speed: 1.7ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.3ms
# Speed: 1.4ms preprocess, 70.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.5ms
# Speed: 1.5ms preprocess, 67.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.0ms
# Speed: 1.8ms preprocess, 67.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.0ms
# Speed: 1.5ms preprocess, 68.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.4ms
# Speed: 2.3ms preprocess, 104.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.0ms
# Speed: 1.7ms preprocess, 77.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.3ms
# Speed: 2.0ms preprocess, 68.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.1ms
# Speed: 1.5ms preprocess, 69.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.4ms
# Speed: 1.7ms preprocess, 69.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.4ms
# Speed: 1.5ms preprocess, 79.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.6ms
# Speed: 1.5ms preprocess, 75.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.2ms
# Speed: 1.9ms preprocess, 87.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.4ms
# Speed: 1.7ms preprocess, 74.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.1ms
# Speed: 1.5ms preprocess, 70.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.9ms
# Speed: 1.4ms preprocess, 67.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.0ms
# Speed: 1.4ms preprocess, 84.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.8ms
# Speed: 1.7ms preprocess, 79.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.8ms
# Speed: 2.1ms preprocess, 69.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.2ms
# Speed: 1.5ms preprocess, 68.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.5ms
# Speed: 1.4ms preprocess, 73.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.9ms
# Speed: 1.4ms preprocess, 71.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.1ms
# Speed: 1.5ms preprocess, 68.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.1ms
# Speed: 1.5ms preprocess, 69.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.6ms
# Speed: 1.7ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.3ms
# Speed: 1.4ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.0ms
# Speed: 1.4ms preprocess, 70.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.8ms
# Speed: 1.5ms preprocess, 68.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.0ms
# Speed: 1.5ms preprocess, 71.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.3ms
# Speed: 1.5ms preprocess, 68.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 1.6ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.7ms
# Speed: 1.6ms preprocess, 66.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.9ms
# Speed: 1.6ms preprocess, 71.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.3ms
# Speed: 1.6ms preprocess, 73.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.2ms
# Speed: 1.4ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 92.8ms
# Speed: 2.3ms preprocess, 92.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 89.2ms
# Speed: 3.4ms preprocess, 89.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 86.0ms
# Speed: 1.6ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.0ms
# Speed: 1.5ms preprocess, 76.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 83.0ms
# Speed: 1.4ms preprocess, 83.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 81.1ms
# Speed: 1.5ms preprocess, 81.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.1ms
# Speed: 1.5ms preprocess, 80.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.8ms
# Speed: 1.4ms preprocess, 75.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.7ms
# Speed: 1.4ms preprocess, 69.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.9ms
# Speed: 1.4ms preprocess, 69.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.5ms
# Speed: 1.4ms preprocess, 69.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.5ms
# Speed: 1.4ms preprocess, 69.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.4ms
# Speed: 1.5ms preprocess, 69.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.1ms
# Speed: 1.4ms preprocess, 72.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.7ms
# Speed: 1.4ms preprocess, 71.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.0ms
# Speed: 1.4ms preprocess, 70.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.6ms
# Speed: 2.0ms preprocess, 69.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.2ms
# Speed: 1.5ms preprocess, 67.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.3ms
# Speed: 1.4ms preprocess, 69.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.1ms
# Speed: 1.5ms preprocess, 69.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.3ms
# Speed: 1.5ms preprocess, 69.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.1ms
# Speed: 1.5ms preprocess, 69.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.9ms
# Speed: 1.8ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.5ms
# Speed: 1.4ms preprocess, 67.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.3ms
# Speed: 1.4ms preprocess, 68.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.2ms
# Speed: 1.5ms preprocess, 73.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.2ms
# Speed: 1.4ms preprocess, 70.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.3ms
# Speed: 1.5ms preprocess, 67.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 90.4ms
# Speed: 1.6ms preprocess, 90.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.0ms
# Speed: 1.6ms preprocess, 78.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.0ms
# Speed: 1.4ms preprocess, 74.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.8ms
# Speed: 1.4ms preprocess, 68.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.6ms
# Speed: 1.4ms preprocess, 72.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.0ms
# Speed: 2.3ms preprocess, 93.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.7ms
# Speed: 1.5ms preprocess, 69.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.1ms
# Speed: 1.4ms preprocess, 66.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.4ms
# Speed: 1.5ms preprocess, 67.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.0ms
# Speed: 1.6ms preprocess, 67.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.2ms
# Speed: 2.3ms preprocess, 65.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.6ms
# Speed: 1.5ms preprocess, 68.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.1ms
# Speed: 1.5ms preprocess, 68.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.6ms
# Speed: 1.5ms preprocess, 66.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.8ms
# Speed: 1.4ms preprocess, 67.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.1ms
# Speed: 1.4ms preprocess, 73.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.5ms
# Speed: 1.5ms preprocess, 69.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.8ms
# Speed: 2.3ms preprocess, 68.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.4ms
# Speed: 1.5ms preprocess, 67.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.5ms
# Speed: 1.7ms preprocess, 79.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.0ms
# Speed: 1.7ms preprocess, 72.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.9ms
# Speed: 1.6ms preprocess, 67.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.0ms
# Speed: 1.5ms preprocess, 70.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.4ms
# Speed: 1.4ms preprocess, 81.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.1ms
# Speed: 1.6ms preprocess, 80.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.3ms
# Speed: 1.5ms preprocess, 65.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.6ms
# Speed: 1.5ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.2ms
# Speed: 2.1ms preprocess, 77.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.5ms
# Speed: 1.9ms preprocess, 83.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.0ms
# Speed: 1.5ms preprocess, 71.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.7ms
# Speed: 1.5ms preprocess, 66.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.1ms
# Speed: 1.5ms preprocess, 70.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.1ms
# Speed: 1.5ms preprocess, 70.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.1ms
# Speed: 1.6ms preprocess, 69.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.9ms
# Speed: 1.4ms preprocess, 67.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.6ms
# Speed: 1.5ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.2ms
# Speed: 1.4ms preprocess, 98.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.2ms
# Speed: 1.8ms preprocess, 79.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.4ms
# Speed: 1.4ms preprocess, 68.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.4ms
# Speed: 1.5ms preprocess, 70.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Video procesado y guardado en: ../videos/output_tienda.avi
